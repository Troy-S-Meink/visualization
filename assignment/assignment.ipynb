# %% [markdown]
# # Assignment: Exploratory Data Analysis
# ### `! git clone https://github.com/DS3001/visualization`
# ### Do Q1 or Q2 or Q3, and Q4. You might want to refer to your work for the data wrangling assignment.

# %%
# Syncing with MY visualization repo with its unique files:
! git clone https://github.com/Troy-S-Meink/visualization
# Out:
# Cloning into 'visualization'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 91 (delta 30), reused 39 (delta 10), pack-reused 24 (from 1)
# Receiving objects: 100% (91/91), 17.15 MiB | 10.15 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# Importing relavant packages:
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Q1.** This question provides some practice doing exploratory data analysis and visualization.
#
# The "relevant" variables for this question are:
#   - `level` - Level of institution (4-year, 2-year)
#   - `aid_value` - The average amount of student aid going to undergraduate recipients
#   - `control` - Public, Private not-for-profit, Private for-profit
#   - `grad_100_value` - percentage of first-time, full-time, degree-seeking undergraduates who complete a degree or certificate program within 100 percent of expected time (bachelor's-seeking group at 4-year institutions)
#
# 1. Load the `./data/college_completion.csv` data with Pandas.
# 2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
# 3. Cross tabulate `control` and `level`. Describe the patterns you see.
# 4. For `grad_100_value`, create a histogram, kernel density plot, boxplot, and statistical description.
# 5. For `grad_100_value`, create a grouped kernel density plot by `control` and by `level`. Describe what you see. Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `grad_100_value` by `level` and `control`. Which institutions appear to have the best graduation rates?
# 6. Create a new variable, `df['levelXcontrol']=df['level']+', '+df['control']` that interacts level and control. Make a grouped kernel density plot. Which institutions appear to have the best graduation rates?
# 7. Make a kernel density plot of `aid_value`. Now group your graph by `level` and `control`. What explains the shape of the graph? Use `groupby` and `.describe` to make grouped calculations of statistical descriptions of `aid_value` by `level` and `control`.
# 8. Make a scatterplot of `grad_100_value` by `aid_value`. Describe what you see. Now make the same plot, grouping by `level` and then `control`. Describe what you see. For which kinds of institutions does aid seem to increase graduation rates?

# %% [markdown]
# **Q2.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. You should have cleaned the `Price` variable in question 2, and you'll need it later for this question.
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?

# %%
# 1. (Pulled from wrangling assignment)
path = './visualization/assignment/data/airbnb_hw.csv' # Pulling the airbnb data
adf = pd.read_csv(path, low_memory=False) # Creating an airbnb dataframe

# Removing the commas from the 'Price' column:
adf['Price'] = adf['Price'].str.replace(',', '')
# Converting the string values to floats:
adf['Price'] = pd.to_numeric(adf['Price'])

# Displaying the price column again to ensure its good-to-go:
#adf['Price'].unique()

# %%
# 2.
adf.head() # Displaying the first few rows of the data

#num_rows = adf.shape[0] # Finding how many rows of observations there are
#print(num_rows)

# There are about 30,000 rows of observations, for about 13 columns.
# There is a mixture of numeric data (such as prices, # of beds, etc.), year/data
#  data, and strings provided info on the characterisitics of the properties.
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
# 3.
# Cross-tabulating "Room Type" and "Property Type" data:
cross_tab = pd.crosstab(adf['Room Type'], adf['Property Type'])
print(cross_tab)

# For B&Bs and houses, renting private rooms is noticeably
#  more common than renting the entire property.
# Out:
# Property Type    Apartment  Bed & Breakfast  Boat  Bungalow  Cabin  Camper/RV  \
# Room Type
# Entire home/apt      15669               13     7         4      1          6
# Private room         10748              155     1         0      1          1
# Shared room            685               12     0         0      0          0
#
# Property Type    Castle  Chalet  Condominium  Dorm  House  Hut  Lighthouse  \
# Room Type
# Entire home/apt       0       0           72     4    752    0           1
# Private room          1       1           22    16   1258    2           0
# Shared room           0       0            0    11     80    0           0
#
# Property Type    Loft  Other  Tent  Townhouse  Treehouse  Villa
# Room Type
# Entire home/apt   392     14     0         83          0      4
# Private room      312     29     4         52          1      4
# Shared room        49      4     0          1          3      0

# %%
# 4.
# Plotting a histogram for the "Price" variable:
adf['Price'].plot(kind='hist', bins=30)
plt.xlabel('Price')
plt.title('Histogram of Price')
# Out:
# Text(0.5, 1.0, 'Histogram of Price')

# %%
# Creating a kernal density plot:
sns.kdeplot(adf['Price'], shade=True)
plt.xlabel('Price')
plt.title('Kernel Density Plot of Price')
# Out:
# <ipython-input-7-e1f414e6978c>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(adf['Price'], shade=True)
# Text(0.5, 1.0, 'Kernel Density Plot of Price')

# %%
# Creating a boxplot:
adf['Price'].plot(kind='box')
plt.xlabel('Price')
plt.title('Box Plot of Price')
# Out:
# Text(0.5, 1.0, 'Box Plot of Price')

# %%
# There does seem to be a lot of outliers and the data
#  is very spread out. Taking the log of Price would
#  go a long ways towards improving its readability.

# Creating a new dataframe, "adf_log_Price"
#  with the "Price" values from the "adf" frame:
price_log = np.log(adf['Price'])

# Plotting a histogram for the log of the Price:
price_log.plot(kind='hist', bins=30)
plt.xlabel('Log of Price')
plt.title('Histogram of Log of Price')
# Out:
# Text(0.5, 1.0, 'Histogram of Log of Price')

# %%
# Creating a kernal density plot with the log of the price:
sns.kdeplot(price_log, shade=True)
plt.xlabel('Log of Price')
plt.title('Kernel Density Plot of Log of Price')
# Out:
# <ipython-input-10-b1a426906afc>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(price_log, shade=True)
# Text(0.5, 1.0, 'Kernel Density Plot of Log of Price')

# %%
# Creating a boxplot of the log price:
price_log.plot(kind='box')
plt.xlabel('Log of Price')
plt.title('Box Plot of Log of Price')
# Out:
# Text(0.5, 1.0, 'Box Plot of Log of Price')

# %%
# 5.
# Creating a scatterplot for "price_log" and "Beds":
sns.scatterplot(x=adf['Beds'], y=price_log)
plt.xlabel('Beds')
plt.ylabel('Log of Price')
plt.title('Scatterplot of Log of Price vs. Beds')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Log of Price vs. Beds')

# %%
# Looking at a description of "Price" conditional on "Beds":
adf.loc[:,['Beds', 'Price']].groupby('Beds').describe()
# Out:
#         Price                                                           \
#         count         mean          std    min     25%    50%      75%
# Beds
# 0.0       2.0    92.000000    38.183766   65.0   78.50   92.0   105.50
# 1.0   20344.0   127.673810   107.047827   10.0   75.00  100.0   155.00
# 2.0    6610.0   199.061271   225.706318   25.0  115.00  160.0   225.00
# 3.0    2071.0   268.118300   303.106942   26.0  140.00  200.0   300.00
# 4.0     783.0   315.332056   353.184402   27.0  150.00  247.0   375.00
# 5.0     284.0   411.500000   672.610659   35.0  189.75  290.0   450.00
# 6.0     177.0   401.768362   417.018431   35.0  199.00  275.0   425.00
# 7.0      45.0   341.377778   220.116631   55.0  177.00  300.0   445.00
# 8.0      24.0   589.041667   793.054934   55.0  243.75  350.0   481.25
# 9.0      15.0   618.000000   233.649616  175.0  447.50  650.0   762.50
# 10.0     16.0   480.187500   296.820534   95.0  291.00  407.5   706.25
# ...

# %%
# As the number of beds increases, there is an upwards
#  trend in the price of the rental. However, this isn't a
#  completely accurate description, as there are some
#  outliers. For instance, the mean price of a property
#  with 12 beds is significantly higher than for one with 16.

# %%
# 6.
# Creating a scatterplot colored by "Room Type":
sns.scatterplot(x=adf['Beds'], y=price_log, hue=adf['Room Type'])
plt.xlabel('Beds')
plt.ylabel('Log of Price')
plt.title('Scatterplot of Log of Price vs. Beds (colored by Room Type)')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Log of Price vs. Beds (colored by Room Type)')

# %%
# Looking at a description of "Price" conditional on "Room Type":
adf.loc[:,['Room Type', 'Price']].groupby('Room Type').describe()
# Out:
#                    Price                                                     \
#                    count        mean         std   min    25%    50%    75%
# Room Type
# Entire home/apt  17024.0  220.796346  242.222346  10.0  135.0  175.0  240.0
# Private room     12609.0   91.919740   67.119678  10.0   65.0   80.0  100.0
# Shared room        845.0   80.514793  110.756196  10.0   45.0   60.0   85.0
#
#
#                      max
# Room Type
# Entire home/apt  10000.0
# Private room      3000.0
# Shared room       2500.0

# %%
# Renting an entire home/apartment is more expensive than
#  only obtaining a private room, which is again, more
#  expensive than getting a shared room. The price of
#  renting an entire property has a greater STD than the others.

# %%
# Creating a scatterplot colored by "Property Type":
sns.scatterplot(x=adf['Beds'], y=price_log, hue=adf['Property Type'])
plt.xlabel('Beds')
plt.ylabel('Log of Price')
plt.title('Scatterplot of Log of Price vs. Beds (colored by Property Type)')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Log of Price vs. Beds (colored by Property Type)')

# %%
# Looking at a description of "Price" conditional on "Property Type":
adf.loc[:,['Property Type', 'Price']].groupby('Property Type').describe()
# Out:
#                    Price                                                \
#                    count        mean         std    min     25%    50%
# Property Type
# Apartment        27102.0  162.045642  181.376882   10.0   85.00  130.0
# Bed & Breakfast    180.0  106.572222   84.701977   30.0   65.00   87.5
# Boat                 8.0  153.625000   49.231051  100.0  120.00  137.5
# Bungalow             4.0  150.750000   46.464144   87.0  133.50  160.5
# Cabin                2.0  165.000000  120.208153   80.0  122.50  165.0
# Camper/RV            7.0  103.571429  102.343958   39.0   47.00   49.0
# Castle               1.0  150.000000         NaN  150.0  150.00  150.0
# Chalet               1.0   99.000000         NaN   99.0   99.00   99.0
# Condominium         94.0  256.585106  249.357946   46.0  131.25  175.0
# Dorm                31.0   76.354839   42.424481   30.0   52.50   65.0
# House             2090.0  156.722967  307.116948   10.0   60.00   85.0
# ...

# %%
# Of the labelled properties, renting a Villa
#  seems to carry the highest mean price at $328.
#  It also sports the highest STD at ~$480.

# %%
# 7.
# Creating a Joint Plot for "price_log" and "Beds":
sns.jointplot(x=adf['Beds'], y=price_log, kind='hex')
plt.xlabel('Beds')
plt.ylabel('Log of Price')
# Out:
# Text(37.722222222222214, 0.5, 'Log of Price')

# %%
# Most properties have 1 or 2 beds, with less having 3 or 4,
#  and signficantly less having more than that. Also, most prices
#  are in the log(3.5) to the log(6.5) range. This indicates
#  that the data we noticed earlier was largely outliers.

# %% [markdown]
# **Q3.** Open the `./data/CBO_data.pdf` file. This contains tax data for 2019, explaining where the money comes from that the U.S. Federal Government Spends in terms of taxation on individuals/families and payroll taxes (the amount that your employer pays in taxes on your wages).
#
# For some context, the Federal government ultimately spent about $4.4 trillion in 2019, which was 21% of GDP (the total monetary value of all goods and services produced within the United States). Individual Income Taxes is the amount individuals pay on their wages to the Federal government, Corporate Income Taxes is the taxes individuals pay on capital gains from investment when they sell stock or other financial instruments, Payroll Taxes is the tax your employer pays on your wages, Excises and Customs Duties are taxes on goods or services like sin taxes on cigarettes or alcohol, and Estate and Gift Taxes are taxes paid on transfers of wealth to other people.
#
# 1. Get the Millions of Families and Billions of Dollars data into a .csv file and load it with Pandas.
# 2. Create a bar plot of individual income taxes by income decile. Explain what the graph shows. Why are some values negative?
# 3. Create a bar plot of Total Federal Taxes by income decile. Which deciles are paying net positive amounts, and which are paying net negative amounts?
# 4. Create a stacked bar plot for which Total Federal Taxes is grouped by Individual Income Taxes, Payroll Taxes, Excises and Customs Duties, and Estate and Gift Taxes. How does the share of taxes paid vary across the adjusted income deciles? (Hint: Are these the kind of data you want to melt?)
# 5. Below the Total line for Millions of Families and Billions of Dollars, there are data for the richest of the richest families. Plot this alongside the bars for the deciles above the Total line. Describe your results.
# 6. Get the Percent Distribution data into a .csv file and load it with Pandas. Create a bar graph of Total Federal Taxes by income decile.
# 7. A tax system is progressive if higher-income and wealthier individuals pay more than lower-income and less wealthy individuals, and it is regressive if the opposite is true. Is the U.S. tax system progressive in terms of amount paid? In terms of the percentage of the overall total?
# 8. Do the rich pay enough in taxes? Defend your answer.

# %% [markdown]
# **Q4.** Go to https://data.cms.gov/search.
# 1. Pick a dataset about something you are interested in. Download the data and data dictionary. If you really can't decide, you can always use this one: https://data.cms.gov/medicare-current-beneficiary-survey-mcbs/medicare-current-beneficiary-survey-data
# 3. Does the data dictionary document how missings are handled? For categorical variables, does it describe the possible values and missing value codes? For the numeric variables, does it describe how missing values are handled? Summarize your opinion of the data dictionary.
# 4. Pick out a few interesting variables, and explain why you find them jointly interesting. Clean those variables, documenting your choices by commenting in the code or in a markdown chunk in a notebook.
# 5. For the variables you select, make a boxplot for each numeric variable and a bar graph for each categorical variable. Do you see any outliers?
# 6. Create a histogram or kernel density plot, and explain what you see. Do the results require any transformations to rescale them?
# 7. Create a scatter plot, and describe the relationship you see.
# 8. Create a table (cross tabulation, variance-covariance, or a `.describe()` five-number summary), and explain what you see.

# %%
# 1.
# Because I am weak-minded, I downloaded the given data:
# From the Medicare website, Fall 2021 survey data:
path = './visualization/assignment/data/sfpuf2021_1_fall.csv' # Pulling the survey data
df = pd.read_csv(path, low_memory=False) # Creating an medicare dataframe

df.head() # Displaying the first few rows of the data
# Out:
#      PUF_ID  SURVEYYR  VERSION  ADM_H_MEDSTA  ADM_H_GHPSW  ADM_H_PDRS  \
# 0  21000003      2021        1             1            2         1.0
# 1  21000004      2021        1             1            2         1.0
# 2  21000005      2021        1             1            2         1.0
# 3  21000011      2021        1             1            2         1.0
# 4  21000012      2021        1             1            1         1.0
#
#    ADM_OP_MDCD  ADM_DUAL_FLAG_YR  ADM_FFS_FLAG_YR  ADM_MA_FLAG_YR  ...  \
# 0            1                 1                3               1  ...
# 1            1                 1                3               1  ...
# 2            1                 1                3               1  ...
# 3            1                 1                3               1  ...
# 4            2                 3                1               3  ...
#
#         PUFF091       PUFF092       PUFF093      PUFF094      PUFF095  \
# ...

# %%
# 2.
# The glossary seems to well-describe the data/variables.
#  It discusses how categorical variables are quantified
#  and the ways in which missing values are dealt with.

# %%
# 3.
# I decided to look at the ADM_OP_MDCD (Medicare-Medicaid dual
#  eligibility) and ADM_LIS_FLAG_YR (Low income subsidy indicator
#  for the yr) variables. I think it would interesting to see the
#  potential overlap between dual Medicare-Medicaid eligibility
#  and low income people. The data is extremely clean, so only
#  requires converting strings to numerical variables. The keys
#  to the data are shown below:

# Medicare-Medicaid dual eligibility
#  1 : Nondual
#  2 : Full dual
#  3 : Partial dual
#  4 : QMB dual

# Low income subsidy indicator for the yr
#  1 : No premium subsidy
#  2 : Part year premium subsidy
#  3 : Full year premium subsidy

# Converting the string values to numeric:
df['ADM_OP_MDCD'] = pd.to_numeric(df['ADM_OP_MDCD'])
df['ADM_LIS_FLAG_YR'] = pd.to_numeric(df['ADM_LIS_FLAG_YR'])

# %%
# 4.
# Creating a bar graph for the ADM_OP_MDCD data:
value_counts = df['ADM_OP_MDCD'].value_counts().sort_index()
value_counts.plot(kind='bar')
plt.xlabel('Medicare-Medicaid dual eligibility')
plt.ylabel('# of Responses')
plt.title('Bar Graph of Medicare-Medicaid dual eligibility')
plt.legend(title='1: Nondual\n2: Full Dual\n3: Partial dual\n4: QMB dual')

# %%
# The vast majority of respondents seemed to be NON-dual

# %%
# Creating a bar graph for the ADM_LIS_FLAG_YR data:
value_counts = df['ADM_LIS_FLAG_YR'].value_counts().sort_index()
value_counts.plot(kind='bar')
plt.xlabel('Low income subsidy indicator for the yr')
plt.ylabel('# of Responses')
plt.title('Bar Graph of Low income subsidy indicator for the yr')
plt.legend(title='1: No premium subsidy\n2: Part year premium subsidy\n3: Full year premium subsidy')

# %%
# Most respondents seemed to either have No subsidy or FULL subsidy

# %%
# 5.
# Creating a kernal density plot for the ADM_OP_MDCD data:
sns.kdeplot(df['ADM_OP_MDCD'], shade=True)
plt.xlabel('Medicare-Medicaid dual eligibility')
plt.title('Kernel Density Plot of Medicare-Medicaid dual eligibility')
plt.legend(title='1: Nondual\n2: Full Dual\n3: Partial dual\n4: QMB dual')
# Out:
# <ipython-input-32-fe12d3e71394>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['ADM_OP_MDCD'], shade=True)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Again, most respondents didn't have dual eligibility.

# %%
# Creating a kernal density plot for the ADM_LIS_FLAG_YR data:
sns.kdeplot(df['ADM_LIS_FLAG_YR'], shade=True)
plt.xlabel('Low income subsidy indicator for the yr')
plt.title('Kernel Density Plot of Low income subsidy indicator for the yr')
plt.legend(title='1: No premium subsidy\n2: Part year premium subsidy\n3: Full year premium subsidy')
# Out:
# <ipython-input-33-4a0b0b6056d9>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['ADM_LIS_FLAG_YR'], shade=True)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# This also agrees with the bar graph that most respondents
#  either had no subsidy or full subsidy.

# %%
# 6.
# Creating a scatterplot for the ADM_OP_MDCD and ADM_LIS_FLAG_YR data:
sns.scatterplot(x=df['ADM_OP_MDCD'], y=df['ADM_LIS_FLAG_YR'])
plt.xlabel('Medicare-Medicaid dual eligibility')
plt.ylabel('Low income subsidy indicator for the yr')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
# Unfortunately since the data is categorical, not much info can
#  be gleamed from the scatterplot. This is because there is simply
#  a grid of points corresponding to the 3x4 variables.

# %%
# 7.
# Looking at a description of ADM_OP_MDCD conditional on "ADM_LIS_FLAG_YR":
df.loc[:,['ADM_LIS_FLAG_YR', 'ADM_OP_MDCD']].groupby('ADM_LIS_FLAG_YR').describe()
# Out:
#                 ADM_OP_MDCD
#                       count      mean       std  min  25%  50%  75%  max
# ADM_LIS_FLAG_YR
# 1                    9752.0  1.002974  0.073665  1.0  1.0  1.0  1.0  4.0
# 2                     192.0  2.166667  0.922853  1.0  2.0  2.0  3.0  4.0
# 3                    2839.0  2.300810  0.857563  1.0  2.0  2.0  3.0  4.0

# %%
# Medicare-Medicaid dual eligibility
#  1 : Nondual
#  2 : Full dual
#  3 : Partial dual
#  4 : QMB dual

# Low income subsidy indicator for the yr
#  1 : No premium subsidy
#  2 : Part year premium subsidy
#  3 : Full year premium subsidy

# It seems most people who do not have subsidized Medicare (1) also
#  aren't dual Medicare-Medicaid recipients (1). This makes sense, as
#  people who are not low income to the point where their health care
#  is subsidized also probably don't need dual coverage. Additionally,
#  respondents with fully subsidized Medicare (3), seemed to be more likely
#  to also require partial or full dual coverage for Medicare and Medicaid
#  (2-3). This also make sense, as people who are economically not very
#  well off would likely require more Medicare/Medicaid assistance.
